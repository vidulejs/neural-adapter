# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import DataLoader

import os
import matplotlib.pyplot as plt
import numpy as np

from model import MLP, MLP_RES, CNN_RES
from dataset import BurgersDatasetBPTT, train_split_files

from utils import clear_memory

from config import (
    DATA_DIR,
    INPUT_SIZE,
    HIDDEN_SIZE,
    OUTPUT_SIZE,
    EPOCHS,
    BATCH_SIZE,
    LR,
    SPLIT,
	UNROLL_STEPS
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from utils import clear_memory, pad_with_ghost_cells

NUM_RES_BLOCKS = 4
KERNEL_SIZE = 5
LR = 5e-5
EPOCHS = 100
EARLY_STOPPING = 30

UNROLL_STEPS=3
checkpoint_name = None
fine_tune = False # continue training the model

unroll_array =[3, 5, 7, 10, 15, 20, 30, 40, 50, 60]
# unroll_array = unroll_array[-2::]
# unroll_array = unroll_array[::-1]
val_loss_array = []
val_loss_full_array = []


for UNROLL_STEPS in unroll_array:
    print(f"Training with unroll steps: {UNROLL_STEPS}")
    print(f"Learning Rate: {LR}")

    # ---------------------------------------------------------------- #

    train_files, val_files = train_split_files()

    train_dataset = BurgersDatasetBPTT(file_paths=train_files, unroll_steps=UNROLL_STEPS)
    val_dataset = BurgersDatasetBPTT(file_paths=val_files, unroll_steps=UNROLL_STEPS)

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

    # ---------------------------------------------------------------- #

    def unroll_loss(x, y, unroll_steps=UNROLL_STEPS):
        if unroll_steps == -1:
            unroll_steps = y.shape[1]

        max_step_loss = 1.0
        loss = torch.tensor(0.0, device=device)
        prev_step = x

        for i in range(unroll_steps):
            # apply periodic boundary conditions
            bc_left = prev_step[:, -1:]
            bc_right = prev_step[:, :1]

            padded_input = pad_with_ghost_cells(prev_step, bc_left, bc_right)
            y_pred = model(padded_input)


            step_loss = torch.clamp(criterion(y_pred, y[:, i]), max=max_step_loss) # gradient clipping
            loss += step_loss
            prev_step = y_pred
            
        return loss / unroll_steps

    def train_bptt(criterion, optimizer, scheduler, model, train_loader, val_loader, device, UNROLL_STEPS, EPOCHS, EARLY_STOPPING):
        unroll_steps = UNROLL_STEPS
        early_stopping = EARLY_STOPPING
        max_gradient_norm = 1.0

        best_epoch = 0
        best_val_loss = float("inf")
        current_lr = optimizer.param_groups[0]['lr']

        loss_history = {"train": [], "val": []}
        print("Starting training...")

        for epoch in range(EPOCHS):
            model.train()
            train_loss = 0.0
            for x, y in train_loader:
                x = x.to(device)
                y = y.to(device)
                
                optimizer.zero_grad()
                loss = unroll_loss(x, y, unroll_steps)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=max_gradient_norm)  # gradient clipping
                optimizer.step()
                train_loss += loss.item()

            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for x, y in val_loader:
                    x = x.to(device)
                    y = y.to(device)
                    # y_pred = model(x)
                    # val_loss += criterion(y_pred, y).item()
                    loss = unroll_loss(x, y, unroll_steps)
                    val_loss += loss.item()

            avg_train = train_loss / len(train_loader)
            avg_val = val_loss / len(val_loader)

            if avg_val < best_val_loss:
                best_val_loss = avg_val
                best_epoch = epoch
                best_lr = current_lr 
                best_model_wts = {k: v.cpu() for k, v in model.state_dict().items()}
                print(f"New best model found at epoch {epoch+1} with val loss {best_val_loss:.6f}")

            # Get the current learning rate from the optimizer
            current_lr = optimizer.param_groups[0]['lr']
            
            print(
                f"Epoch {epoch+1}, "
                f"Train Loss: {avg_train:.6f}, "
                f"Val Loss: {avg_val:.6f}, "
                f"LR: {current_lr:.2e}"
            )

            loss_history["train"].append(avg_train)
            loss_history["val"].append(avg_val)

            # Step the scheduler at the end of each epoch
            scheduler.step()

            if epoch - best_epoch > early_stopping:
                print(f"Early stopping triggered. Stopping training at epoch {epoch+1}.")
                break

        # Load best model weights
        model.load_state_dict(best_model_wts)

        print("Finished training.")

        loss_history["best_lr"] = best_lr

        return loss_history

    model = CNN_RES(
        hidden_channels=HIDDEN_SIZE,
        num_blocks=NUM_RES_BLOCKS,
        kernel_size=KERNEL_SIZE
    )
    
    if checkpoint_name is not None:
        model.load_state_dict(torch.load(f"models/{checkpoint_name}.pth", weights_only=True)) # pre-trained model
    model.to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=1e-11)

    model_name = "CNN_RES_UNROLL_" + str(UNROLL_STEPS)
    checkpoint_name = model_name

    if not os.path.exists(f"models/{model_name}.pth") or fine_tune:
        loss_history = train_bptt(criterion, optimizer, scheduler, model, train_loader, val_loader, device, UNROLL_STEPS, EPOCHS, EARLY_STOPPING)
        torch.save(model.state_dict(), f"models/{model_name}.pth")
        print(f"Model saved")

        last_lr = loss_history["best_lr"]
        clamp = lambda x, min_v, max_v: max(min_v, min(x, max_v))
        LR = clamp(last_lr, 1e-12, 1e-5) # LR for next model

        if not fine_tune:
            #save loss_history to file
            with open(f"models/loss_{model_name}.txt", "w") as f:
                for key, values in loss_history.items():
                    f.write(f"{key}: {values}\n")

            plt.figure(figsize=(8, 4), dpi=300)
            plt.plot(loss_history["train"], label="Train Loss")
            plt.plot(loss_history["val"], label="Val Loss")
            plt.xlabel("Epoch")
            plt.ylabel("Loss")
            plt.title(f"Unroll steps = {UNROLL_STEPS}")
            plt.yscale("log")
            plt.tight_layout()
            plt.grid(which="both", linestyle="--", linewidth=0.5)
            plt.legend()
            plt.ylim(1e-4, 1e-0)
            plt.tight_layout()
            plt.savefig(f"models/loss_{model_name}.png")
            plt.show()

    else:
        model.load_state_dict(torch.load(f"models/{model_name}.pth", weights_only=True))
        model.eval()
        print("Model loaded")

    # ---------------------------------------------------------------- #

    #evaluate model on val_loader
    val_loss = 0.0
    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = unroll_loss(x, y, UNROLL_STEPS)
            val_loss += loss.item()

    avg_val_loss = val_loss / len(val_loader)
    val_loss_array.append(avg_val_loss)
    print(f"Model validation Loss over {UNROLL_STEPS} steps: {avg_val_loss:.6f}")

    # full rollout
    val_dataset = BurgersDatasetBPTT(file_paths=val_files, unroll_steps=-1)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

    val_loss = 0.0
    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device)
            loss = unroll_loss(x, y, -1)
            val_loss += loss.item()

    avg_val_loss = val_loss / len(val_loader)
    val_loss_full_array.append(avg_val_loss)
    print(f"Model validation Loss over full sequence: {avg_val_loss:.6f}")

    clear_memory()
# Out:
# Training with unroll steps: 3
# Learning Rate: 5e-05
# Found 169 simulations.
# Splitting into 84 training and 85 validation files.
# Starting training...
# New best model found at epoch 1 with val loss 0.097250
# Epoch 1, Train Loss: 0.059071, Val Loss: 0.097250, LR: 5.00e-05
# New best model found at epoch 2 with val loss 0.009342
# Epoch 2, Train Loss: 0.022388, Val Loss: 0.009342, LR: 5.00e-05
# Epoch 3, Train Loss: 0.019895, Val Loss: 0.056609, LR: 5.00e-05
# Epoch 4, Train Loss: 0.016400, Val Loss: 0.046553, LR: 4.99e-05
# Epoch 5, Train Loss: 0.014813, Val Loss: 0.029743, LR: 4.98e-05
# Epoch 6, Train Loss: 0.017076, Val Loss: 0.024131, LR: 4.97e-05
# Epoch 7, Train Loss: 0.012534, Val Loss: 0.041293, LR: 4.96e-05
# New best model found at epoch 8 with val loss 0.005858
# Epoch 8, Train Loss: 0.012248, Val Loss: 0.005858, LR: 4.94e-05
# Epoch 9, Train Loss: 0.011699, Val Loss: 0.007173, LR: 4.92e-05
# Epoch 10, Train Loss: 0.011419, Val Loss: 0.008733, LR: 4.90e-05
# Epoch 11, Train Loss: 0.011143, Val Loss: 0.013322, LR: 4.88e-05
# Epoch 12, Train Loss: 0.011873, Val Loss: 0.006334, LR: 4.85e-05
# New best model found at epoch 13 with val loss 0.004557
# Epoch 13, Train Loss: 0.011323, Val Loss: 0.004557, LR: 4.82e-05
# Epoch 14, Train Loss: 0.009566, Val Loss: 0.007941, LR: 4.79e-05
# Epoch 15, Train Loss: 0.009745, Val Loss: 0.018199, LR: 4.76e-05
# Epoch 16, Train Loss: 0.009726, Val Loss: 0.011501, LR: 4.73e-05
# Epoch 17, Train Loss: 0.008472, Val Loss: 0.004964, LR: 4.69e-05
# Epoch 18, Train Loss: 0.008579, Val Loss: 0.006964, LR: 4.65e-05
# Epoch 19, Train Loss: 0.010023, Val Loss: 0.013536, LR: 4.61e-05
# Epoch 20, Train Loss: 0.007897, Val Loss: 0.008576, LR: 4.57e-05
# New best model found at epoch 21 with val loss 0.003902
# Epoch 21, Train Loss: 0.007683, Val Loss: 0.003902, LR: 4.52e-05
# Epoch 22, Train Loss: 0.007325, Val Loss: 0.004642, LR: 4.48e-05
# Epoch 23, Train Loss: 0.008091, Val Loss: 0.008369, LR: 4.43e-05
# Epoch 24, Train Loss: 0.007357, Val Loss: 0.004375, LR: 4.38e-05
# New best model found at epoch 25 with val loss 0.003607
# Epoch 25, Train Loss: 0.007044, Val Loss: 0.003607, LR: 4.32e-05
# New best model found at epoch 26 with val loss 0.003368
# Epoch 26, Train Loss: 0.006740, Val Loss: 0.003368, LR: 4.27e-05
# Epoch 27, Train Loss: 0.006731, Val Loss: 0.007733, LR: 4.21e-05
# Epoch 28, Train Loss: 0.006744, Val Loss: 0.005564, LR: 4.15e-05
# Epoch 29, Train Loss: 0.006157, Val Loss: 0.010559, LR: 4.09e-05
# Epoch 30, Train Loss: 0.006896, Val Loss: 0.007197, LR: 4.03e-05
# Epoch 31, Train Loss: 0.006931, Val Loss: 0.005108, LR: 3.97e-05
# Epoch 32, Train Loss: 0.005722, Val Loss: 0.013086, LR: 3.91e-05
# Epoch 33, Train Loss: 0.005727, Val Loss: 0.004335, LR: 3.84e-05
# Epoch 34, Train Loss: 0.005609, Val Loss: 0.004647, LR: 3.77e-05
# New best model found at epoch 35 with val loss 0.002333
# Epoch 35, Train Loss: 0.005533, Val Loss: 0.002333, LR: 3.70e-05
# New best model found at epoch 36 with val loss 0.002303
# Epoch 36, Train Loss: 0.005837, Val Loss: 0.002303, LR: 3.63e-05
# Epoch 37, Train Loss: 0.005671, Val Loss: 0.003331, LR: 3.56e-05
# Epoch 38, Train Loss: 0.005356, Val Loss: 0.005636, LR: 3.49e-05
# Epoch 39, Train Loss: 0.005149, Val Loss: 0.003395, LR: 3.42e-05
# Epoch 40, Train Loss: 0.005266, Val Loss: 0.007943, LR: 3.35e-05
# Epoch 41, Train Loss: 0.005434, Val Loss: 0.010848, LR: 3.27e-05
# Epoch 42, Train Loss: 0.005359, Val Loss: 0.002913, LR: 3.20e-05
# Epoch 43, Train Loss: 0.004740, Val Loss: 0.004009, LR: 3.12e-05
# Epoch 44, Train Loss: 0.004814, Val Loss: 0.003604, LR: 3.05e-05
# New best model found at epoch 45 with val loss 0.001959
# Epoch 45, Train Loss: 0.004400, Val Loss: 0.001959, LR: 2.97e-05
# Epoch 46, Train Loss: 0.004735, Val Loss: 0.004254, LR: 2.89e-05
# Epoch 47, Train Loss: 0.004193, Val Loss: 0.003025, LR: 2.81e-05
# Epoch 48, Train Loss: 0.004097, Val Loss: 0.005420, LR: 2.74e-05
# Epoch 49, Train Loss: 0.003800, Val Loss: 0.002195, LR: 2.66e-05
# Epoch 50, Train Loss: 0.003726, Val Loss: 0.004492, LR: 2.58e-05
# Epoch 51, Train Loss: 0.003952, Val Loss: 0.002715, LR: 2.50e-05
# Epoch 52, Train Loss: 0.003890, Val Loss: 0.003226, LR: 2.42e-05
# Epoch 53, Train Loss: 0.003618, Val Loss: 0.002964, LR: 2.34e-05
# Epoch 54, Train Loss: 0.003362, Val Loss: 0.002429, LR: 2.26e-05
# Epoch 55, Train Loss: 0.003098, Val Loss: 0.002936, LR: 2.19e-05
# Epoch 56, Train Loss: 0.003609, Val Loss: 0.004476, LR: 2.11e-05
# Epoch 57, Train Loss: 0.003388, Val Loss: 0.002482, LR: 2.03e-05
# New best model found at epoch 58 with val loss 0.001930
# Epoch 58, Train Loss: 0.002942, Val Loss: 0.001930, LR: 1.95e-05
# Epoch 59, Train Loss: 0.002899, Val Loss: 0.002199, LR: 1.88e-05
# Epoch 60, Train Loss: 0.003010, Val Loss: 0.003755, LR: 1.80e-05
# Epoch 61, Train Loss: 0.002899, Val Loss: 0.001985, LR: 1.73e-05
# New best model found at epoch 62 with val loss 0.001681
# Epoch 62, Train Loss: 0.002763, Val Loss: 0.001681, LR: 1.65e-05
# Epoch 63, Train Loss: 0.002899, Val Loss: 0.002279, LR: 1.58e-05
# Epoch 64, Train Loss: 0.002596, Val Loss: 0.002981, LR: 1.51e-05
# Epoch 65, Train Loss: 0.002627, Val Loss: 0.002094, LR: 1.44e-05
# Epoch 66, Train Loss: 0.002447, Val Loss: 0.002661, LR: 1.37e-05
# New best model found at epoch 67 with val loss 0.001432
# Epoch 67, Train Loss: 0.002359, Val Loss: 0.001432, LR: 1.30e-05
# Epoch 68, Train Loss: 0.002291, Val Loss: 0.001653, LR: 1.23e-05
# Epoch 69, Train Loss: 0.002212, Val Loss: 0.001931, LR: 1.16e-05
# Epoch 70, Train Loss: 0.002263, Val Loss: 0.002099, LR: 1.09e-05
# Epoch 71, Train Loss: 0.002117, Val Loss: 0.002783, LR: 1.03e-05
# Epoch 72, Train Loss: 0.002059, Val Loss: 0.001481, LR: 9.68e-06
# Epoch 73, Train Loss: 0.001897, Val Loss: 0.002160, LR: 9.06e-06
# Epoch 74, Train Loss: 0.002043, Val Loss: 0.001673, LR: 8.47e-06
# Epoch 75, Train Loss: 0.002078, Val Loss: 0.002036, LR: 7.89e-06
# New best model found at epoch 76 with val loss 0.001337
# Epoch 76, Train Loss: 0.001761, Val Loss: 0.001337, LR: 7.32e-06
# New best model found at epoch 77 with val loss 0.001332
# Epoch 77, Train Loss: 0.001957, Val Loss: 0.001332, LR: 6.78e-06
# Epoch 78, Train Loss: 0.001830, Val Loss: 0.001829, LR: 6.25e-06
# Epoch 79, Train Loss: 0.001933, Val Loss: 0.004175, LR: 5.74e-06
# Epoch 80, Train Loss: 0.001747, Val Loss: 0.003211, LR: 5.25e-06
# Epoch 81, Train Loss: 0.001645, Val Loss: 0.001374, LR: 4.77e-06
# Epoch 82, Train Loss: 0.001774, Val Loss: 0.002036, LR: 4.32e-06
# New best model found at epoch 83 with val loss 0.001214
# Epoch 83, Train Loss: 0.001541, Val Loss: 0.001214, LR: 3.89e-06
# Epoch 84, Train Loss: 0.001561, Val Loss: 0.001885, LR: 3.48e-06
# Epoch 85, Train Loss: 0.001564, Val Loss: 0.001462, LR: 3.09e-06
# Epoch 86, Train Loss: 0.001447, Val Loss: 0.001273, LR: 2.72e-06
# Epoch 87, Train Loss: 0.001441, Val Loss: 0.001262, LR: 2.38e-06
# Epoch 88, Train Loss: 0.001489, Val Loss: 0.001550, LR: 2.06e-06
# Epoch 89, Train Loss: 0.001487, Val Loss: 0.001398, LR: 1.76e-06
# Epoch 90, Train Loss: 0.001449, Val Loss: 0.001240, LR: 1.48e-06
# New best model found at epoch 91 with val loss 0.001163
# Epoch 91, Train Loss: 0.001362, Val Loss: 0.001163, LR: 1.22e-06
# Epoch 92, Train Loss: 0.001520, Val Loss: 0.001838, LR: 9.93e-07
# Epoch 93, Train Loss: 0.001397, Val Loss: 0.001531, LR: 7.85e-07
# Epoch 94, Train Loss: 0.001337, Val Loss: 0.001378, LR: 6.02e-07
# Epoch 95, Train Loss: 0.001350, Val Loss: 0.001312, LR: 4.43e-07
# Epoch 96, Train Loss: 0.001385, Val Loss: 0.001213, LR: 3.08e-07
# Epoch 97, Train Loss: 0.001369, Val Loss: 0.001602, LR: 1.97e-07
# Epoch 98, Train Loss: 0.001380, Val Loss: 0.004036, LR: 1.11e-07
# New best model found at epoch 99 with val loss 0.001144
# Epoch 99, Train Loss: 0.001422, Val Loss: 0.001144, LR: 4.93e-08
# Epoch 100, Train Loss: 0.001382, Val Loss: 0.001895, LR: 1.23e-08
# Finished training.
# Model saved
# Model validation Loss over 3 steps: 0.001144
# Model validation Loss over full sequence: 0.032014
# CUDA before -> allocated: 42 MB, reserved: 338 MB
# CUDA after  -> allocated: 42 MB, reserved: 76 MB
# Remaining live CUDA tensors: 146
# Training with unroll steps: 5
# Learning Rate: 1.1096086273282313e-07
# Found 169 simulations.
# Splitting into 84 training and 85 validation files.
# Starting training...
# /home/dan/venvs/torch/lib/python3.11/site-packages/torch/__init__.py:1021: FutureWarning: `torch.distributed.reduce_op` is deprecated, please use `torch.distributed.ReduceOp` instead
#   return isinstance(obj, torch.Tensor)
# New best model found at epoch 1 with val loss 0.002057
# Epoch 1, Train Loss: 0.001785, Val Loss: 0.002057, LR: 1.11e-07
# Epoch 2, Train Loss: 0.001792, Val Loss: 0.002415, LR: 1.11e-07
# New best model found at epoch 3 with val loss 0.001856
# Epoch 3, Train Loss: 0.001733, Val Loss: 0.001856, LR: 1.11e-07
# New best model found at epoch 4 with val loss 0.001740
# Epoch 4, Train Loss: 0.001606, Val Loss: 0.001740, LR: 1.11e-07
# Epoch 5, Train Loss: 0.001680, Val Loss: 0.002322, LR: 1.11e-07
# Epoch 6, Train Loss: 0.001637, Val Loss: 0.001842, LR: 1.10e-07
# Epoch 7, Train Loss: 0.001756, Val Loss: 0.002092, LR: 1.10e-07
# Epoch 8, Train Loss: 0.001718, Val Loss: 0.002020, LR: 1.10e-07
# Epoch 9, Train Loss: 0.001771, Val Loss: 0.001968, LR: 1.09e-07
# Epoch 10, Train Loss: 0.001728, Val Loss: 0.002012, LR: 1.09e-07
# Epoch 11, Train Loss: 0.001677, Val Loss: 0.002071, LR: 1.08e-07
# Epoch 12, Train Loss: 0.001680, Val Loss: 0.001894, LR: 1.08e-07
# Epoch 13, Train Loss: 0.001650, Val Loss: 0.002211, LR: 1.07e-07
# Epoch 14, Train Loss: 0.001712, Val Loss: 0.002048, LR: 1.06e-07
# New best model found at epoch 15 with val loss 0.001691
# Epoch 15, Train Loss: 0.001726, Val Loss: 0.001691, LR: 1.06e-07
# New best model found at epoch 16 with val loss 0.001681
# Epoch 16, Train Loss: 0.001685, Val Loss: 0.001681, LR: 1.05e-07
# Epoch 17, Train Loss: 0.001677, Val Loss: 0.002336, LR: 1.04e-07
# Epoch 18, Train Loss: 0.001650, Val Loss: 0.002125, LR: 1.03e-07
# Epoch 19, Train Loss: 0.001662, Val Loss: 0.002123, LR: 1.02e-07
# Epoch 20, Train Loss: 0.001616, Val Loss: 0.001788, LR: 1.01e-07
# Epoch 21, Train Loss: 0.001676, Val Loss: 0.001708, LR: 1.00e-07
# Epoch 22, Train Loss: 0.001514, Val Loss: 0.002569, LR: 9.93e-08
# New best model found at epoch 23 with val loss 0.001641
# Epoch 23, Train Loss: 0.001683, Val Loss: 0.001641, LR: 9.82e-08
# Epoch 24, Train Loss: 0.001721, Val Loss: 0.001752, LR: 9.71e-08
# Epoch 25, Train Loss: 0.001730, Val Loss: 0.001689, LR: 9.59e-08
# Epoch 26, Train Loss: 0.001585, Val Loss: 0.002357, LR: 9.47e-08
# Epoch 27, Train Loss: 0.001626, Val Loss: 0.001765, LR: 9.35e-08
# Epoch 28, Train Loss: 0.001666, Val Loss: 0.002360, LR: 9.22e-08
# Epoch 29, Train Loss: 0.001821, Val Loss: 0.001877, LR: 9.08e-08
# Epoch 30, Train Loss: 0.001778, Val Loss: 0.002038, LR: 8.95e-08
# Epoch 31, Train Loss: 0.001621, Val Loss: 0.001661, LR: 8.81e-08
# Epoch 32, Train Loss: 0.001655, Val Loss: 0.001909, LR: 8.67e-08
# Epoch 33, Train Loss: 0.001724, Val Loss: 0.001874, LR: 8.52e-08
# Epoch 34, Train Loss: 0.001585, Val Loss: 0.001714, LR: 8.37e-08
# Epoch 35, Train Loss: 0.001652, Val Loss: 0.001676, LR: 8.22e-08
# New best model found at epoch 36 with val loss 0.001640
# Epoch 36, Train Loss: 0.001747, Val Loss: 0.001640, LR: 8.07e-08
# Epoch 37, Train Loss: 0.001693, Val Loss: 0.002368, LR: 7.91e-08
# Epoch 38, Train Loss: 0.001762, Val Loss: 0.001680, LR: 7.75e-08
# Epoch 39, Train Loss: 0.001680, Val Loss: 0.002133, LR: 7.59e-08
# Epoch 40, Train Loss: 0.001691, Val Loss: 0.002125, LR: 7.43e-08
# Epoch 41, Train Loss: 0.001732, Val Loss: 0.004113, LR: 7.26e-08
# Epoch 42, Train Loss: 0.001582, Val Loss: 0.001729, LR: 7.10e-08
# Epoch 43, Train Loss: 0.001599, Val Loss: 0.002429, LR: 6.93e-08
# Epoch 44, Train Loss: 0.001598, Val Loss: 0.002057, LR: 6.76e-08
# Epoch 45, Train Loss: 0.001597, Val Loss: 0.001670, LR: 6.59e-08
# Epoch 46, Train Loss: 0.001735, Val Loss: 0.001727, LR: 6.42e-08
# Epoch 47, Train Loss: 0.001571, Val Loss: 0.001998, LR: 6.24e-08
# Epoch 48, Train Loss: 0.001610, Val Loss: 0.002088, LR: 6.07e-08
# Epoch 49, Train Loss: 0.001550, Val Loss: 0.001725, LR: 5.90e-08
# Epoch 50, Train Loss: 0.001630, Val Loss: 0.001794, LR: 5.72e-08
# New best model found at epoch 51 with val loss 0.001636
# Epoch 51, Train Loss: 0.001736, Val Loss: 0.001636, LR: 5.55e-08
# Epoch 52, Train Loss: 0.001669, Val Loss: 0.001866, LR: 5.37e-08
# Epoch 53, Train Loss: 0.001637, Val Loss: 0.001736, LR: 5.20e-08
# Epoch 54, Train Loss: 0.001688, Val Loss: 0.002161, LR: 5.03e-08
# Epoch 55, Train Loss: 0.001549, Val Loss: 0.002051, LR: 4.85e-08
# Epoch 56, Train Loss: 0.001623, Val Loss: 0.001695, LR: 4.68e-08
# Epoch 57, Train Loss: 0.001606, Val Loss: 0.001851, LR: 4.51e-08
# Epoch 58, Train Loss: 0.001611, Val Loss: 0.002068, LR: 4.34e-08
# Epoch 59, Train Loss: 0.001574, Val Loss: 0.001870, LR: 4.17e-08
# Epoch 60, Train Loss: 0.001694, Val Loss: 0.001775, LR: 4.00e-08
# Epoch 61, Train Loss: 0.001724, Val Loss: 0.001939, LR: 3.83e-08
# Epoch 62, Train Loss: 0.001681, Val Loss: 0.001728, LR: 3.67e-08
# Epoch 63, Train Loss: 0.001558, Val Loss: 0.001964, LR: 3.51e-08
# Epoch 64, Train Loss: 0.001621, Val Loss: 0.001854, LR: 3.35e-08
# Epoch 65, Train Loss: 0.001601, Val Loss: 0.001756, LR: 3.19e-08
# Epoch 66, Train Loss: 0.001684, Val Loss: 0.001971, LR: 3.03e-08
# Epoch 67, Train Loss: 0.001584, Val Loss: 0.001773, LR: 2.88e-08
# Epoch 68, Train Loss: 0.001677, Val Loss: 0.002585, LR: 2.72e-08
# Epoch 69, Train Loss: 0.001646, Val Loss: 0.001814, LR: 2.58e-08
# Epoch 70, Train Loss: 0.001614, Val Loss: 0.002607, LR: 2.43e-08
# Epoch 71, Train Loss: 0.001724, Val Loss: 0.001724, LR: 2.29e-08
# Epoch 72, Train Loss: 0.001606, Val Loss: 0.001932, LR: 2.15e-08
# Epoch 73, Train Loss: 0.001542, Val Loss: 0.001944, LR: 2.01e-08
# Epoch 74, Train Loss: 0.001592, Val Loss: 0.001729, LR: 1.88e-08
# Epoch 75, Train Loss: 0.001656, Val Loss: 0.001848, LR: 1.75e-08
# Epoch 76, Train Loss: 0.001647, Val Loss: 0.001987, LR: 1.63e-08
# Epoch 77, Train Loss: 0.001670, Val Loss: 0.002252, LR: 1.50e-08
# Epoch 78, Train Loss: 0.001602, Val Loss: 0.002588, LR: 1.39e-08
# Epoch 79, Train Loss: 0.001613, Val Loss: 0.001737, LR: 1.27e-08
# Epoch 80, Train Loss: 0.001653, Val Loss: 0.001911, LR: 1.17e-08
# Epoch 81, Train Loss: 0.001591, Val Loss: 0.002156, LR: 1.06e-08
# Epoch 82, Train Loss: 0.001648, Val Loss: 0.001914, LR: 9.60e-09
# Early stopping triggered. Stopping training at epoch 82.
# Finished training.
# Model saved
# Model validation Loss over 5 steps: 0.001636
# Model validation Loss over full sequence: 0.028337
# CUDA before -> allocated: 49 MB, reserved: 516 MB
# CUDA after  -> allocated: 49 MB, reserved: 216 MB
# Remaining live CUDA tensors: 146
# Training with unroll steps: 7
# Learning Rate: 5.7227956775817164e-08
# Found 169 simulations.
# Splitting into 84 training and 85 validation files.
# Starting training...
# New best model found at epoch 1 with val loss 0.003833
# Epoch 1, Train Loss: 0.002258, Val Loss: 0.003833, LR: 5.72e-08
# New best model found at epoch 2 with val loss 0.002568
# Epoch 2, Train Loss: 0.002268, Val Loss: 0.002568, LR: 5.72e-08
# Epoch 3, Train Loss: 0.002172, Val Loss: 0.003573, LR: 5.72e-08
# Epoch 4, Train Loss: 0.002390, Val Loss: 0.003322, LR: 5.71e-08
# New best model found at epoch 5 with val loss 0.002363
# Epoch 5, Train Loss: 0.002206, Val Loss: 0.002363, LR: 5.70e-08
# New best model found at epoch 6 with val loss 0.002274
# Epoch 6, Train Loss: 0.002063, Val Loss: 0.002274, LR: 5.69e-08
# Epoch 7, Train Loss: 0.002103, Val Loss: 0.002497, LR: 5.67e-08
# Epoch 8, Train Loss: 0.002053, Val Loss: 0.002863, LR: 5.65e-08
# Epoch 9, Train Loss: 0.002340, Val Loss: 0.002641, LR: 5.63e-08
# Epoch 10, Train Loss: 0.001978, Val Loss: 0.002380, LR: 5.61e-08
# Epoch 11, Train Loss: 0.002138, Val Loss: 0.002417, LR: 5.58e-08
# Epoch 12, Train Loss: 0.002153, Val Loss: 0.002478, LR: 5.55e-08
# Epoch 13, Train Loss: 0.002239, Val Loss: 0.002390, LR: 5.52e-08
# Epoch 14, Train Loss: 0.002167, Val Loss: 0.002676, LR: 5.49e-08
# Epoch 15, Train Loss: 0.002065, Val Loss: 0.002470, LR: 5.45e-08
# Epoch 16, Train Loss: 0.002245, Val Loss: 0.002639, LR: 5.41e-08
# Epoch 17, Train Loss: 0.002322, Val Loss: 0.002726, LR: 5.37e-08
# Epoch 18, Train Loss: 0.002070, Val Loss: 0.002314, LR: 5.32e-08
# Epoch 19, Train Loss: 0.002121, Val Loss: 0.002673, LR: 5.28e-08
# New best model found at epoch 20 with val loss 0.002174
# Epoch 20, Train Loss: 0.002177, Val Loss: 0.002174, LR: 5.23e-08
# Epoch 21, Train Loss: 0.002129, Val Loss: 0.002528, LR: 5.18e-08
# Epoch 22, Train Loss: 0.002023, Val Loss: 0.002608, LR: 5.12e-08
# Epoch 23, Train Loss: 0.002322, Val Loss: 0.003870, LR: 5.07e-08
# Epoch 24, Train Loss: 0.002077, Val Loss: 0.003378, LR: 5.01e-08
# Epoch 25, Train Loss: 0.002087, Val Loss: 0.002350, LR: 4.95e-08
# Epoch 26, Train Loss: 0.002291, Val Loss: 0.002886, LR: 4.88e-08
# Epoch 27, Train Loss: 0.002154, Val Loss: 0.002188, LR: 4.82e-08
# Epoch 28, Train Loss: 0.002077, Val Loss: 0.002421, LR: 4.75e-08
# Epoch 29, Train Loss: 0.002041, Val Loss: 0.002567, LR: 4.69e-08
# Epoch 30, Train Loss: 0.002017, Val Loss: 0.003278, LR: 4.62e-08
# Epoch 31, Train Loss: 0.002244, Val Loss: 0.002950, LR: 4.54e-08
# Epoch 32, Train Loss: 0.002075, Val Loss: 0.002468, LR: 4.47e-08
# Epoch 33, Train Loss: 0.002059, Val Loss: 0.003614, LR: 4.39e-08
# Epoch 34, Train Loss: 0.002096, Val Loss: 0.002441, LR: 4.32e-08
# Epoch 35, Train Loss: 0.002110, Val Loss: 0.002798, LR: 4.24e-08
# Epoch 36, Train Loss: 0.002014, Val Loss: 0.002259, LR: 4.16e-08
# Epoch 37, Train Loss: 0.002111, Val Loss: 0.002674, LR: 4.08e-08
# Epoch 38, Train Loss: 0.002202, Val Loss: 0.002621, LR: 4.00e-08
# Epoch 39, Train Loss: 0.002000, Val Loss: 0.003382, LR: 3.92e-08
# Epoch 40, Train Loss: 0.001969, Val Loss: 0.002906, LR: 3.83e-08
# Epoch 41, Train Loss: 0.002243, Val Loss: 0.003434, LR: 3.75e-08
# Epoch 42, Train Loss: 0.002295, Val Loss: 0.003210, LR: 3.66e-08
# Epoch 43, Train Loss: 0.002063, Val Loss: 0.002569, LR: 3.57e-08
# Epoch 44, Train Loss: 0.002128, Val Loss: 0.003059, LR: 3.49e-08
# Epoch 45, Train Loss: 0.002094, Val Loss: 0.002253, LR: 3.40e-08
# Epoch 46, Train Loss: 0.002296, Val Loss: 0.002806, LR: 3.31e-08
# Epoch 47, Train Loss: 0.002113, Val Loss: 0.003197, LR: 3.22e-08
# Epoch 48, Train Loss: 0.002130, Val Loss: 0.002408, LR: 3.13e-08
# Epoch 49, Train Loss: 0.002229, Val Loss: 0.002438, LR: 3.04e-08
# Epoch 50, Train Loss: 0.002285, Val Loss: 0.002537, LR: 2.95e-08
# Epoch 51, Train Loss: 0.001994, Val Loss: 0.002740, LR: 2.86e-08
# Early stopping triggered. Stopping training at epoch 51.
# Finished training.
# Model saved
# Model validation Loss over 7 steps: 0.002174
# Model validation Loss over full sequence: 0.028087
# CUDA before -> allocated: 44 MB, reserved: 696 MB
# CUDA after  -> allocated: 44 MB, reserved: 196 MB
# Remaining live CUDA tensors: 146
# Training with unroll steps: 10
# Learning Rate: 5.277433776090343e-08
# Found 169 simulations.
# Splitting into 84 training and 85 validation files.
# Starting training...
# New best model found at epoch 1 with val loss 0.004806
# Epoch 1, Train Loss: 0.003196, Val Loss: 0.004806, LR: 5.28e-08
# New best model found at epoch 2 with val loss 0.004583
# Epoch 2, Train Loss: 0.003072, Val Loss: 0.004583, LR: 5.28e-08
# New best model found at epoch 3 with val loss 0.003991
# Epoch 3, Train Loss: 0.003061, Val Loss: 0.003991, LR: 5.27e-08
# New best model found at epoch 4 with val loss 0.003856
# Epoch 4, Train Loss: 0.003024, Val Loss: 0.003856, LR: 5.27e-08
# Epoch 5, Train Loss: 0.002886, Val Loss: 0.003989, LR: 5.26e-08
# New best model found at epoch 6 with val loss 0.003392
# Epoch 6, Train Loss: 0.002902, Val Loss: 0.003392, LR: 5.24e-08
# New best model found at epoch 7 with val loss 0.003153
# Epoch 7, Train Loss: 0.002815, Val Loss: 0.003153, LR: 5.23e-08
# Epoch 8, Train Loss: 0.002867, Val Loss: 0.004373, LR: 5.21e-08
# Epoch 9, Train Loss: 0.002815, Val Loss: 0.007342, LR: 5.19e-08
# Epoch 10, Train Loss: 0.003057, Val Loss: 0.005074, LR: 5.17e-08
# Epoch 11, Train Loss: 0.002669, Val Loss: 0.004442, LR: 5.15e-08
# Epoch 12, Train Loss: 0.003067, Val Loss: 0.004177, LR: 5.12e-08
# Epoch 13, Train Loss: 0.002860, Val Loss: 0.003796, LR: 5.09e-08
# Epoch 14, Train Loss: 0.002798, Val Loss: 0.003321, LR: 5.06e-08
# Epoch 15, Train Loss: 0.002810, Val Loss: 0.004233, LR: 5.03e-08
# Epoch 16, Train Loss: 0.003167, Val Loss: 0.005041, LR: 4.99e-08
# Epoch 17, Train Loss: 0.003048, Val Loss: 0.003781, LR: 4.95e-08
# Epoch 18, Train Loss: 0.003087, Val Loss: 0.003662, LR: 4.91e-08
# Epoch 19, Train Loss: 0.002880, Val Loss: 0.005929, LR: 4.87e-08
# New best model found at epoch 20 with val loss 0.002924
# Epoch 20, Train Loss: 0.003047, Val Loss: 0.002924, LR: 4.82e-08
# Epoch 21, Train Loss: 0.003011, Val Loss: 0.004438, LR: 4.77e-08
# Epoch 22, Train Loss: 0.003102, Val Loss: 0.003950, LR: 4.72e-08
# Epoch 23, Train Loss: 0.002908, Val Loss: 0.003929, LR: 4.67e-08
# Epoch 24, Train Loss: 0.002935, Val Loss: 0.005225, LR: 4.62e-08
# Epoch 25, Train Loss: 0.002807, Val Loss: 0.004166, LR: 4.56e-08
# Epoch 26, Train Loss: 0.003027, Val Loss: 0.003804, LR: 4.50e-08
# Epoch 27, Train Loss: 0.002848, Val Loss: 0.006075, LR: 4.45e-08
# Epoch 28, Train Loss: 0.002848, Val Loss: 0.003947, LR: 4.38e-08
# Epoch 29, Train Loss: 0.002950, Val Loss: 0.007086, LR: 4.32e-08
# Epoch 30, Train Loss: 0.003011, Val Loss: 0.003109, LR: 4.26e-08
# Epoch 31, Train Loss: 0.002821, Val Loss: 0.004601, LR: 4.19e-08
# Epoch 32, Train Loss: 0.003045, Val Loss: 0.003103, LR: 4.12e-08
# Epoch 33, Train Loss: 0.002782, Val Loss: 0.004955, LR: 4.05e-08
# Epoch 34, Train Loss: 0.002904, Val Loss: 0.003190, LR: 3.98e-08
# Epoch 35, Train Loss: 0.002703, Val Loss: 0.003499, LR: 3.91e-08
# Epoch 36, Train Loss: 0.002784, Val Loss: 0.003205, LR: 3.84e-08
# Epoch 37, Train Loss: 0.002747, Val Loss: 0.005399, LR: 3.76e-08
# Epoch 38, Train Loss: 0.002957, Val Loss: 0.003133, LR: 3.69e-08
# Epoch 39, Train Loss: 0.002729, Val Loss: 0.003882, LR: 3.61e-08
# Epoch 40, Train Loss: 0.002889, Val Loss: 0.004009, LR: 3.53e-08
# Epoch 41, Train Loss: 0.002983, Val Loss: 0.003724, LR: 3.45e-08
# Epoch 42, Train Loss: 0.002741, Val Loss: 0.005727, LR: 3.38e-08
# Epoch 43, Train Loss: 0.002734, Val Loss: 0.003037, LR: 3.30e-08
# Epoch 44, Train Loss: 0.002814, Val Loss: 0.005474, LR: 3.21e-08
# Epoch 45, Train Loss: 0.002743, Val Loss: 0.004002, LR: 3.13e-08
# New best model found at epoch 46 with val loss 0.002792
# Epoch 46, Train Loss: 0.002873, Val Loss: 0.002792, LR: 3.05e-08
# Epoch 47, Train Loss: 0.002879, Val Loss: 0.004710, LR: 2.97e-08
# Epoch 48, Train Loss: 0.002814, Val Loss: 0.003798, LR: 2.89e-08
# Epoch 49, Train Loss: 0.002825, Val Loss: 0.003333, LR: 2.80e-08
# Epoch 50, Train Loss: 0.002723, Val Loss: 0.004460, LR: 2.72e-08
# Epoch 51, Train Loss: 0.002951, Val Loss: 0.004204, LR: 2.64e-08
# Epoch 52, Train Loss: 0.002932, Val Loss: 0.003592, LR: 2.56e-08
# Epoch 53, Train Loss: 0.002791, Val Loss: 0.004342, LR: 2.47e-08
# Epoch 54, Train Loss: 0.002632, Val Loss: 0.003896, LR: 2.39e-08
# Epoch 55, Train Loss: 0.002706, Val Loss: 0.003709, LR: 2.31e-08
# Epoch 56, Train Loss: 0.002844, Val Loss: 0.004376, LR: 2.23e-08
# Epoch 57, Train Loss: 0.002839, Val Loss: 0.006562, LR: 2.14e-08
# Epoch 58, Train Loss: 0.002787, Val Loss: 0.003367, LR: 2.06e-08
# Epoch 59, Train Loss: 0.002881, Val Loss: 0.003408, LR: 1.98e-08
# Epoch 60, Train Loss: 0.002907, Val Loss: 0.003554, LR: 1.90e-08
# Epoch 61, Train Loss: 0.002839, Val Loss: 0.003063, LR: 1.82e-08
# Epoch 62, Train Loss: 0.002921, Val Loss: 0.005789, LR: 1.75e-08
# Epoch 63, Train Loss: 0.002693, Val Loss: 0.004537, LR: 1.67e-08
# Epoch 64, Train Loss: 0.002874, Val Loss: 0.003061, LR: 1.59e-08
# Epoch 65, Train Loss: 0.002924, Val Loss: 0.007157, LR: 1.52e-08
# Epoch 66, Train Loss: 0.003031, Val Loss: 0.003419, LR: 1.44e-08
# Epoch 67, Train Loss: 0.002797, Val Loss: 0.003024, LR: 1.37e-08
# Epoch 68, Train Loss: 0.002866, Val Loss: 0.003575, LR: 1.30e-08
# Epoch 69, Train Loss: 0.002778, Val Loss: 0.005956, LR: 1.23e-08
# Epoch 70, Train Loss: 0.002975, Val Loss: 0.004207, LR: 1.16e-08
# Epoch 71, Train Loss: 0.002808, Val Loss: 0.005639, LR: 1.09e-08
# Epoch 72, Train Loss: 0.002987, Val Loss: 0.003713, LR: 1.02e-08
# Epoch 73, Train Loss: 0.003128, Val Loss: 0.003624, LR: 9.58e-09
# Epoch 74, Train Loss: 0.002697, Val Loss: 0.003732, LR: 8.95e-09
# Epoch 75, Train Loss: 0.002853, Val Loss: 0.003315, LR: 8.33e-09
# Epoch 76, Train Loss: 0.002801, Val Loss: 0.003631, LR: 7.74e-09
# Epoch 77, Train Loss: 0.002661, Val Loss: 0.003898, LR: 7.16e-09
# Early stopping triggered. Stopping training at epoch 77.
# Finished training.
# Model saved
# Model validation Loss over 10 steps: 0.002792
# Model validation Loss over full sequence: 0.026108
# CUDA before -> allocated: 45 MB, reserved: 964 MB
# CUDA after  -> allocated: 45 MB, reserved: 190 MB
# Remaining live CUDA tensors: 146
# Training with unroll steps: 15
# Learning Rate: 3.1335694366893345e-08
# Found 169 simulations.
# Splitting into 84 training and 85 validation files.
# Starting training...
# New best model found at epoch 1 with val loss 0.012911
# Epoch 1, Train Loss: 0.004566, Val Loss: 0.012911, LR: 3.13e-08
# New best model found at epoch 2 with val loss 0.012431
# Epoch 2, Train Loss: 0.004674, Val Loss: 0.012431, LR: 3.13e-08
# New best model found at epoch 3 with val loss 0.011722
# Epoch 3, Train Loss: 0.004834, Val Loss: 0.011722, LR: 3.13e-08
# New best model found at epoch 4 with val loss 0.008451
# Epoch 4, Train Loss: 0.004676, Val Loss: 0.008451, LR: 3.13e-08
# Epoch 5, Train Loss: 0.005147, Val Loss: 0.013490, LR: 3.12e-08
# Epoch 6, Train Loss: 0.004680, Val Loss: 0.013131, LR: 3.11e-08
# Epoch 7, Train Loss: 0.004647, Val Loss: 0.010846, LR: 3.11e-08
# New best model found at epoch 8 with val loss 0.006920
# Epoch 8, Train Loss: 0.004571, Val Loss: 0.006920, LR: 3.10e-08
# Epoch 9, Train Loss: 0.005305, Val Loss: 0.011389, LR: 3.08e-08
# Epoch 10, Train Loss: 0.004126, Val Loss: 0.015743, LR: 3.07e-08
# Epoch 11, Train Loss: 0.005532, Val Loss: 0.014679, LR: 3.06e-08
# Epoch 12, Train Loss: 0.004938, Val Loss: 0.020651, LR: 3.04e-08
# Epoch 13, Train Loss: 0.004871, Val Loss: 0.010439, LR: 3.02e-08
# Epoch 14, Train Loss: 0.004696, Val Loss: 0.017229, LR: 3.00e-08
# Epoch 15, Train Loss: 0.004518, Val Loss: 0.009568, LR: 2.98e-08
# Epoch 16, Train Loss: 0.005187, Val Loss: 0.020760, LR: 2.96e-08
# Epoch 17, Train Loss: 0.004736, Val Loss: 0.010496, LR: 2.94e-08
# Epoch 18, Train Loss: 0.008852, Val Loss: 0.049618, LR: 2.92e-08
# Epoch 19, Train Loss: 0.004304, Val Loss: 0.008753, LR: 2.89e-08
# Epoch 20, Train Loss: 0.004798, Val Loss: 0.016135, LR: 2.86e-08
# Epoch 21, Train Loss: 0.007516, Val Loss: 0.035168, LR: 2.83e-08
# Epoch 22, Train Loss: 0.004179, Val Loss: 0.008925, LR: 2.80e-08
# Epoch 23, Train Loss: 0.004601, Val Loss: 0.014306, LR: 2.77e-08
# Epoch 24, Train Loss: 0.004514, Val Loss: 0.013032, LR: 2.74e-08
# Epoch 25, Train Loss: 0.004386, Val Loss: 0.009845, LR: 2.71e-08
# Epoch 26, Train Loss: 0.004219, Val Loss: 0.013337, LR: 2.67e-08
# Epoch 27, Train Loss: 0.005791, Val Loss: 0.025371, LR: 2.64e-08
# Epoch 28, Train Loss: 0.004343, Val Loss: 0.014559, LR: 2.60e-08
# Epoch 29, Train Loss: 0.004799, Val Loss: 0.010217, LR: 2.57e-08
# Epoch 30, Train Loss: 0.004868, Val Loss: 0.027127, LR: 2.53e-08
# Epoch 31, Train Loss: 0.004562, Val Loss: 0.009893, LR: 2.49e-08
# Epoch 32, Train Loss: 0.004211, Val Loss: 0.016011, LR: 2.45e-08
# Epoch 33, Train Loss: 0.004205, Val Loss: 0.011434, LR: 2.41e-08
# Epoch 34, Train Loss: 0.004573, Val Loss: 0.008285, LR: 2.36e-08
# Epoch 35, Train Loss: 0.004507, Val Loss: 0.011891, LR: 2.32e-08
# Epoch 36, Train Loss: 0.004603, Val Loss: 0.011211, LR: 2.28e-08
# Epoch 37, Train Loss: 0.004426, Val Loss: 0.011120, LR: 2.23e-08
# Epoch 38, Train Loss: 0.005397, Val Loss: 0.013824, LR: 2.19e-08
# Epoch 39, Train Loss: 0.004794, Val Loss: 0.015738, LR: 2.14e-08
# Early stopping triggered. Stopping training at epoch 39.
# Finished training.
# Model saved
# Model validation Loss over 15 steps: 0.006920
# Model validation Loss over full sequence: 0.041823
# CUDA before -> allocated: 41 MB, reserved: 1592 MB
# CUDA after  -> allocated: 41 MB, reserved: 56 MB
# Remaining live CUDA tensors: 146
# Training with unroll steps: 20
# Learning Rate: 3.10582622818581e-08
# Found 169 simulations.
# Splitting into 84 training and 85 validation files.
# Starting training...
# New best model found at epoch 1 with val loss 0.013639
# Epoch 1, Train Loss: 0.006680, Val Loss: 0.013639, LR: 3.11e-08
# New best model found at epoch 2 with val loss 0.009792
# Epoch 2, Train Loss: 0.006840, Val Loss: 0.009792, LR: 3.11e-08
# Epoch 3, Train Loss: 0.006656, Val Loss: 0.016708, LR: 3.10e-08
# Epoch 4, Train Loss: 0.006369, Val Loss: 0.009879, LR: 3.10e-08
# Epoch 5, Train Loss: 0.006214, Val Loss: 0.009968, LR: 3.09e-08
# New best model found at epoch 6 with val loss 0.008955
# Epoch 6, Train Loss: 0.006027, Val Loss: 0.008955, LR: 3.09e-08
# New best model found at epoch 7 with val loss 0.008927
# Epoch 7, Train Loss: 0.006094, Val Loss: 0.008927, LR: 3.08e-08
# Epoch 8, Train Loss: 0.006263, Val Loss: 0.009137, LR: 3.07e-08
# Epoch 9, Train Loss: 0.007013, Val Loss: 0.017080, LR: 3.06e-08
# New best model found at epoch 10 with val loss 0.008287
# Epoch 10, Train Loss: 0.006639, Val Loss: 0.008287, LR: 3.04e-08
# Epoch 11, Train Loss: 0.006101, Val Loss: 0.008309, LR: 3.03e-08
# Epoch 12, Train Loss: 0.006529, Val Loss: 0.021512, LR: 3.01e-08
# Epoch 13, Train Loss: 0.005589, Val Loss: 0.010619, LR: 3.00e-08
# Epoch 14, Train Loss: 0.006277, Val Loss: 0.009449, LR: 2.98e-08
# Epoch 15, Train Loss: 0.006024, Val Loss: 0.011051, LR: 2.96e-08
# Epoch 16, Train Loss: 0.006424, Val Loss: 0.010516, LR: 2.94e-08
# Epoch 17, Train Loss: 0.006130, Val Loss: 0.014254, LR: 2.91e-08
# Epoch 18, Train Loss: 0.005771, Val Loss: 0.011453, LR: 2.89e-08
# Epoch 19, Train Loss: 0.006290, Val Loss: 0.010619, LR: 2.86e-08
# Epoch 20, Train Loss: 0.005972, Val Loss: 0.021543, LR: 2.84e-08
# Epoch 21, Train Loss: 0.005937, Val Loss: 0.012445, LR: 2.81e-08
# Epoch 22, Train Loss: 0.005958, Val Loss: 0.008392, LR: 2.78e-08
# Epoch 23, Train Loss: 0.006095, Val Loss: 0.012277, LR: 2.75e-08
# Epoch 24, Train Loss: 0.006157, Val Loss: 0.008579, LR: 2.72e-08
# Epoch 25, Train Loss: 0.006513, Val Loss: 0.010576, LR: 2.69e-08
# Epoch 26, Train Loss: 0.006170, Val Loss: 0.018559, LR: 2.65e-08
# Epoch 27, Train Loss: 0.005957, Val Loss: 0.010003, LR: 2.62e-08
# Epoch 28, Train Loss: 0.006268, Val Loss: 0.010198, LR: 2.58e-08
# Epoch 29, Train Loss: 0.005888, Val Loss: 0.009023, LR: 2.54e-08
# Epoch 30, Train Loss: 0.006508, Val Loss: 0.017711, LR: 2.50e-08
# New best model found at epoch 31 with val loss 0.007660
# Epoch 31, Train Loss: 0.006003, Val Loss: 0.007660, LR: 2.47e-08
# Epoch 32, Train Loss: 0.006065, Val Loss: 0.011979, LR: 2.43e-08
# Epoch 33, Train Loss: 0.006713, Val Loss: 0.010741, LR: 2.39e-08
# New best model found at epoch 34 with val loss 0.006726
# Epoch 34, Train Loss: 0.006243, Val Loss: 0.006726, LR: 2.34e-08
# Epoch 35, Train Loss: 0.006702, Val Loss: 0.011094, LR: 2.30e-08
# Epoch 36, Train Loss: 0.006311, Val Loss: 0.009902, LR: 2.26e-08
# Epoch 37, Train Loss: 0.006180, Val Loss: 0.025360, LR: 2.21e-08
# Epoch 38, Train Loss: 0.005728, Val Loss: 0.012481, LR: 2.17e-08
# Epoch 39, Train Loss: 0.007778, Val Loss: 0.010525, LR: 2.12e-08
# Epoch 40, Train Loss: 0.005382, Val Loss: 0.015829, LR: 2.08e-08
# Epoch 41, Train Loss: 0.005560, Val Loss: 0.009718, LR: 2.03e-08
# Epoch 42, Train Loss: 0.007059, Val Loss: 0.006759, LR: 1.99e-08
# Epoch 43, Train Loss: 0.007307, Val Loss: 0.009336, LR: 1.94e-08
# Epoch 44, Train Loss: 0.006520, Val Loss: 0.010248, LR: 1.89e-08
# Epoch 45, Train Loss: 0.006284, Val Loss: 0.010805, LR: 1.84e-08
# Epoch 46, Train Loss: 0.006493, Val Loss: 0.008667, LR: 1.80e-08
# Epoch 47, Train Loss: 0.007001, Val Loss: 0.008517, LR: 1.75e-08
# Epoch 48, Train Loss: 0.007152, Val Loss: 0.010639, LR: 1.70e-08
# Epoch 49, Train Loss: 0.006449, Val Loss: 0.014095, LR: 1.65e-08
# Epoch 50, Train Loss: 0.005973, Val Loss: 0.010406, LR: 1.60e-08
# Epoch 51, Train Loss: 0.006286, Val Loss: 0.012428, LR: 1.55e-08
# Epoch 52, Train Loss: 0.006006, Val Loss: 0.016921, LR: 1.50e-08
# Epoch 53, Train Loss: 0.006207, Val Loss: 0.011112, LR: 1.46e-08
# Epoch 54, Train Loss: 0.006160, Val Loss: 0.009177, LR: 1.41e-08
# Epoch 55, Train Loss: 0.005935, Val Loss: 0.011706, LR: 1.36e-08
# Epoch 56, Train Loss: 0.005721, Val Loss: 0.019070, LR: 1.31e-08
# Epoch 57, Train Loss: 0.005870, Val Loss: 0.008362, LR: 1.26e-08
# Epoch 58, Train Loss: 0.006518, Val Loss: 0.015529, LR: 1.21e-08
# Epoch 59, Train Loss: 0.005934, Val Loss: 0.011612, LR: 1.17e-08
# Epoch 60, Train Loss: 0.006954, Val Loss: 0.011433, LR: 1.12e-08
# Epoch 61, Train Loss: 0.006483, Val Loss: 0.008131, LR: 1.07e-08
# Epoch 62, Train Loss: 0.006424, Val Loss: 0.010287, LR: 1.03e-08
# Epoch 63, Train Loss: 0.006409, Val Loss: 0.008667, LR: 9.82e-09
# Epoch 64, Train Loss: 0.006256, Val Loss: 0.009754, LR: 9.37e-09
# Epoch 65, Train Loss: 0.006405, Val Loss: 0.011439, LR: 8.92e-09
# Early stopping triggered. Stopping training at epoch 65.
# Finished training.
# Model saved
# Model validation Loss over 20 steps: 0.006726
# Model validation Loss over full sequence: 0.032243
# CUDA before -> allocated: 46 MB, reserved: 1870 MB
# CUDA after  -> allocated: 46 MB, reserved: 212 MB
# Remaining live CUDA tensors: 146
# Training with unroll steps: 30
# Learning Rate: 2.38523765750067e-08
# Found 169 simulations.
# Splitting into 84 training and 85 validation files.
# Starting training...
# New best model found at epoch 1 with val loss 0.018539
# Epoch 1, Train Loss: 0.013557, Val Loss: 0.018539, LR: 2.39e-08
# Epoch 2, Train Loss: 0.016110, Val Loss: 0.036233, LR: 2.38e-08
# Epoch 3, Train Loss: 0.014050, Val Loss: 0.021937, LR: 2.38e-08
# Epoch 4, Train Loss: 0.012605, Val Loss: 0.045438, LR: 2.38e-08
# Epoch 5, Train Loss: 0.012443, Val Loss: 0.040076, LR: 2.38e-08
# Epoch 6, Train Loss: 0.012605, Val Loss: 0.037751, LR: 2.37e-08
# Epoch 7, Train Loss: 0.014661, Val Loss: 0.021430, LR: 2.36e-08
# Epoch 8, Train Loss: 0.013578, Val Loss: 0.019377, LR: 2.36e-08
# Epoch 9, Train Loss: 0.012408, Val Loss: 0.047983, LR: 2.35e-08
# Epoch 10, Train Loss: 0.011896, Val Loss: 0.062276, LR: 2.34e-08
# Epoch 11, Train Loss: 0.022678, Val Loss: 0.036190, LR: 2.33e-08
# Epoch 12, Train Loss: 0.015895, Val Loss: 0.026420, LR: 2.31e-08
# Epoch 13, Train Loss: 0.012622, Val Loss: 0.018659, LR: 2.30e-08
# Epoch 14, Train Loss: 0.016696, Val Loss: 0.030878, LR: 2.29e-08
# Epoch 15, Train Loss: 0.012088, Val Loss: 0.039585, LR: 2.27e-08
# Epoch 16, Train Loss: 0.013141, Val Loss: 0.028891, LR: 2.26e-08
# Epoch 17, Train Loss: 0.013184, Val Loss: 0.068261, LR: 2.24e-08
# Epoch 18, Train Loss: 0.012986, Val Loss: 0.028060, LR: 2.22e-08
# Epoch 19, Train Loss: 0.015773, Val Loss: 0.026295, LR: 2.20e-08
# Epoch 20, Train Loss: 0.013917, Val Loss: 0.047889, LR: 2.18e-08
# Epoch 21, Train Loss: 0.014934, Val Loss: 0.020816, LR: 2.16e-08
# Epoch 22, Train Loss: 0.011924, Val Loss: 0.026293, LR: 2.14e-08
# Epoch 23, Train Loss: 0.013955, Val Loss: 0.020383, LR: 2.11e-08
# Epoch 24, Train Loss: 0.015628, Val Loss: 0.054610, LR: 2.09e-08
# Epoch 25, Train Loss: 0.017670, Val Loss: 0.042363, LR: 2.06e-08
# Epoch 26, Train Loss: 0.012797, Val Loss: 0.032530, LR: 2.04e-08
# Epoch 27, Train Loss: 0.014147, Val Loss: 0.040455, LR: 2.01e-08
# Epoch 28, Train Loss: 0.014224, Val Loss: 0.067961, LR: 1.98e-08
# Epoch 29, Train Loss: 0.012162, Val Loss: 0.023829, LR: 1.95e-08
# Epoch 30, Train Loss: 0.017477, Val Loss: 0.031932, LR: 1.92e-08
# Epoch 31, Train Loss: 0.014422, Val Loss: 0.026189, LR: 1.89e-08
# Epoch 32, Train Loss: 0.011943, Val Loss: 0.033317, LR: 1.86e-08
# Early stopping triggered. Stopping training at epoch 32.
# Finished training.
# Model saved
# Model validation Loss over 30 steps: 0.018539
# Model validation Loss over full sequence: 0.050443
# CUDA before -> allocated: 41 MB, reserved: 3126 MB
# CUDA after  -> allocated: 41 MB, reserved: 58 MB
# Remaining live CUDA tensors: 146
# Training with unroll steps: 40
# Learning Rate: 2.38523765750067e-08
# Found 169 simulations.
# Splitting into 84 training and 85 validation files.
# Starting training...
# New best model found at epoch 1 with val loss 0.044440
# Epoch 1, Train Loss: 0.016354, Val Loss: 0.044440, LR: 2.39e-08
# New best model found at epoch 2 with val loss 0.027011
# Epoch 2, Train Loss: 0.015727, Val Loss: 0.027011, LR: 2.38e-08
# New best model found at epoch 3 with val loss 0.024665
# Epoch 3, Train Loss: 0.017869, Val Loss: 0.024665, LR: 2.38e-08
# Epoch 4, Train Loss: 0.018684, Val Loss: 0.067986, LR: 2.38e-08
# New best model found at epoch 5 with val loss 0.017461
# Epoch 5, Train Loss: 0.015610, Val Loss: 0.017461, LR: 2.38e-08
# Epoch 6, Train Loss: 0.017244, Val Loss: 0.031392, LR: 2.37e-08
# Epoch 7, Train Loss: 0.016040, Val Loss: 0.044275, LR: 2.36e-08
# Epoch 8, Train Loss: 0.016633, Val Loss: 0.069029, LR: 2.36e-08
# Epoch 9, Train Loss: 0.016812, Val Loss: 0.042884, LR: 2.35e-08
# Epoch 10, Train Loss: 0.014619, Val Loss: 0.019112, LR: 2.34e-08
# Epoch 11, Train Loss: 0.016614, Val Loss: 0.030990, LR: 2.33e-08
# Epoch 12, Train Loss: 0.015334, Val Loss: 0.029573, LR: 2.31e-08
# Epoch 13, Train Loss: 0.017107, Val Loss: 0.032885, LR: 2.30e-08
# Epoch 14, Train Loss: 0.016530, Val Loss: 0.026603, LR: 2.29e-08
# Epoch 15, Train Loss: 0.015610, Val Loss: 0.036423, LR: 2.27e-08
# Epoch 16, Train Loss: 0.016187, Val Loss: 0.036102, LR: 2.26e-08
# Epoch 17, Train Loss: 0.015996, Val Loss: 0.038264, LR: 2.24e-08
# Epoch 18, Train Loss: 0.015518, Val Loss: 0.055666, LR: 2.22e-08
# Epoch 19, Train Loss: 0.016121, Val Loss: 0.038438, LR: 2.20e-08
# Epoch 20, Train Loss: 0.016183, Val Loss: 0.040218, LR: 2.18e-08
# Epoch 21, Train Loss: 0.016381, Val Loss: 0.019163, LR: 2.16e-08
# Epoch 22, Train Loss: 0.016068, Val Loss: 0.046990, LR: 2.14e-08
# Epoch 23, Train Loss: 0.015402, Val Loss: 0.032026, LR: 2.11e-08
# Epoch 24, Train Loss: 0.014624, Val Loss: 0.033142, LR: 2.09e-08
# Epoch 25, Train Loss: 0.015748, Val Loss: 0.034197, LR: 2.06e-08
# Epoch 26, Train Loss: 0.015537, Val Loss: 0.062745, LR: 2.04e-08
# Epoch 27, Train Loss: 0.016372, Val Loss: 0.033287, LR: 2.01e-08
# Epoch 28, Train Loss: 0.015367, Val Loss: 0.028446, LR: 1.98e-08
# Epoch 29, Train Loss: 0.017188, Val Loss: 0.071187, LR: 1.95e-08
# Epoch 30, Train Loss: 0.015626, Val Loss: 0.060238, LR: 1.92e-08
# Epoch 31, Train Loss: 0.017762, Val Loss: 0.026413, LR: 1.89e-08
# Epoch 32, Train Loss: 0.015831, Val Loss: 0.020563, LR: 1.86e-08
# Epoch 33, Train Loss: 0.015966, Val Loss: 0.035504, LR: 1.83e-08
# Epoch 34, Train Loss: 0.016779, Val Loss: 0.060352, LR: 1.80e-08
# Epoch 35, Train Loss: 0.016572, Val Loss: 0.028067, LR: 1.77e-08
# Epoch 36, Train Loss: 0.016687, Val Loss: 0.052989, LR: 1.73e-08
# Early stopping triggered. Stopping training at epoch 36.
# Finished training.
# Model saved
# Model validation Loss over 40 steps: 0.017461
# Model validation Loss over full sequence: 0.041381
# CUDA before -> allocated: 41 MB, reserved: 3672 MB
# CUDA after  -> allocated: 41 MB, reserved: 218 MB
# Remaining live CUDA tensors: 146
# Training with unroll steps: 50
# Learning Rate: 2.3799469919413412e-08
# Found 169 simulations.
# Splitting into 84 training and 85 validation files.
# Starting training...
# New best model found at epoch 1 with val loss 0.044495
# Epoch 1, Train Loss: 0.024165, Val Loss: 0.044495, LR: 2.38e-08
# Epoch 2, Train Loss: 0.023826, Val Loss: 0.070369, LR: 2.38e-08
# Epoch 3, Train Loss: 0.023301, Val Loss: 0.084548, LR: 2.38e-08
# New best model found at epoch 4 with val loss 0.038100
# Epoch 4, Train Loss: 0.022205, Val Loss: 0.038100, LR: 2.37e-08
# Epoch 5, Train Loss: 0.023455, Val Loss: 0.038663, LR: 2.37e-08
# Epoch 6, Train Loss: 0.021537, Val Loss: 0.089576, LR: 2.37e-08
# Epoch 7, Train Loss: 0.026134, Val Loss: 0.081667, LR: 2.36e-08
# Epoch 8, Train Loss: 0.022460, Val Loss: 0.054974, LR: 2.35e-08
# Epoch 9, Train Loss: 0.022947, Val Loss: 0.050002, LR: 2.34e-08
# Epoch 10, Train Loss: 0.020915, Val Loss: 0.078875, LR: 2.33e-08
# Epoch 11, Train Loss: 0.022554, Val Loss: 0.102793, LR: 2.32e-08
# Epoch 12, Train Loss: 0.024062, Val Loss: 0.040981, LR: 2.31e-08
# New best model found at epoch 13 with val loss 0.032030
# Epoch 13, Train Loss: 0.022230, Val Loss: 0.032030, LR: 2.30e-08
# Epoch 14, Train Loss: 0.022567, Val Loss: 0.059367, LR: 2.28e-08
# Epoch 15, Train Loss: 0.023861, Val Loss: 0.066732, LR: 2.27e-08
# New best model found at epoch 16 with val loss 0.029448
# Epoch 16, Train Loss: 0.023534, Val Loss: 0.029448, LR: 2.25e-08
# Epoch 17, Train Loss: 0.021917, Val Loss: 0.059538, LR: 2.23e-08
# Epoch 18, Train Loss: 0.022147, Val Loss: 0.072718, LR: 2.21e-08
# Epoch 19, Train Loss: 0.021116, Val Loss: 0.059437, LR: 2.19e-08
# Epoch 20, Train Loss: 0.022656, Val Loss: 0.031233, LR: 2.17e-08
# Epoch 21, Train Loss: 0.021585, Val Loss: 0.074672, LR: 2.15e-08
# Epoch 22, Train Loss: 0.024992, Val Loss: 0.059576, LR: 2.13e-08
# Epoch 23, Train Loss: 0.023985, Val Loss: 0.041648, LR: 2.11e-08
# Epoch 24, Train Loss: 0.022150, Val Loss: 0.078285, LR: 2.08e-08
# Epoch 25, Train Loss: 0.021873, Val Loss: 0.051864, LR: 2.06e-08
# Epoch 26, Train Loss: 0.023038, Val Loss: 0.046116, LR: 2.03e-08
# Epoch 27, Train Loss: 0.023328, Val Loss: 0.084263, LR: 2.00e-08
# Epoch 28, Train Loss: 0.019789, Val Loss: 0.055731, LR: 1.98e-08
# Epoch 29, Train Loss: 0.022389, Val Loss: 0.045552, LR: 1.95e-08
# Epoch 30, Train Loss: 0.022742, Val Loss: 0.059962, LR: 1.92e-08
# Epoch 31, Train Loss: 0.024746, Val Loss: 0.055938, LR: 1.89e-08
# Epoch 32, Train Loss: 0.023546, Val Loss: 0.038024, LR: 1.86e-08
# Epoch 33, Train Loss: 0.023083, Val Loss: 0.041911, LR: 1.83e-08
# Epoch 34, Train Loss: 0.022537, Val Loss: 0.048384, LR: 1.80e-08
# Epoch 35, Train Loss: 0.025065, Val Loss: 0.053996, LR: 1.76e-08
# Epoch 36, Train Loss: 0.026088, Val Loss: 0.114593, LR: 1.73e-08
# Epoch 37, Train Loss: 0.021176, Val Loss: 0.048596, LR: 1.70e-08
# Epoch 38, Train Loss: 0.023010, Val Loss: 0.050877, LR: 1.66e-08
# Epoch 39, Train Loss: 0.022123, Val Loss: 0.058547, LR: 1.63e-08
# Epoch 40, Train Loss: 0.024568, Val Loss: 0.054124, LR: 1.59e-08
# Epoch 41, Train Loss: 0.021516, Val Loss: 0.038775, LR: 1.56e-08
# Epoch 42, Train Loss: 0.021853, Val Loss: 0.082257, LR: 1.52e-08
# Epoch 43, Train Loss: 0.021939, Val Loss: 0.082150, LR: 1.49e-08
# Epoch 44, Train Loss: 0.022477, Val Loss: 0.100194, LR: 1.45e-08
# Epoch 45, Train Loss: 0.022901, Val Loss: 0.076284, LR: 1.41e-08
# Epoch 46, Train Loss: 0.022453, Val Loss: 0.085582, LR: 1.38e-08
# Epoch 47, Train Loss: 0.020956, Val Loss: 0.074535, LR: 1.34e-08
# Early stopping triggered. Stopping training at epoch 47.
# Finished training.
# Model saved
# Model validation Loss over 50 steps: 0.029448
# Model validation Loss over full sequence: 0.057049
# CUDA before -> allocated: 45 MB, reserved: 4574 MB
# CUDA after  -> allocated: 45 MB, reserved: 214 MB
# Remaining live CUDA tensors: 146
# Training with unroll steps: 60
# Learning Rate: 2.266741293316265e-08
# Found 169 simulations.
# Splitting into 84 training and 85 validation files.
# Starting training...
# New best model found at epoch 1 with val loss 0.066965
# Epoch 1, Train Loss: 0.044790, Val Loss: 0.066965, LR: 2.27e-08
# New best model found at epoch 2 with val loss 0.037449
# Epoch 2, Train Loss: 0.045750, Val Loss: 0.037449, LR: 2.27e-08
# Epoch 3, Train Loss: 0.043843, Val Loss: 0.125809, LR: 2.26e-08
# Epoch 4, Train Loss: 0.051625, Val Loss: 0.121789, LR: 2.26e-08
# Epoch 5, Train Loss: 0.042985, Val Loss: 0.102901, LR: 2.26e-08
# Epoch 6, Train Loss: 0.041401, Val Loss: 0.113987, LR: 2.25e-08
# Epoch 7, Train Loss: 0.045094, Val Loss: 0.065264, LR: 2.25e-08
# Epoch 8, Train Loss: 0.044075, Val Loss: 0.153011, LR: 2.24e-08
# Epoch 9, Train Loss: 0.052327, Val Loss: 0.161741, LR: 2.23e-08
# Epoch 10, Train Loss: 0.044579, Val Loss: 0.164512, LR: 2.22e-08
# Epoch 11, Train Loss: 0.043770, Val Loss: 0.161401, LR: 2.21e-08
# Epoch 12, Train Loss: 0.042591, Val Loss: 0.117934, LR: 2.20e-08
# Epoch 13, Train Loss: 0.045934, Val Loss: 0.163672, LR: 2.19e-08
# Epoch 14, Train Loss: 0.048262, Val Loss: 0.071235, LR: 2.17e-08
# Epoch 15, Train Loss: 0.045970, Val Loss: 0.302029, LR: 2.16e-08
# Epoch 16, Train Loss: 0.045004, Val Loss: 0.157310, LR: 2.14e-08
# Epoch 17, Train Loss: 0.044700, Val Loss: 0.101711, LR: 2.13e-08
# Epoch 18, Train Loss: 0.048107, Val Loss: 0.082209, LR: 2.11e-08
# Epoch 19, Train Loss: 0.042497, Val Loss: 0.132161, LR: 2.09e-08
# Epoch 20, Train Loss: 0.043320, Val Loss: 0.188878, LR: 2.07e-08
# Epoch 21, Train Loss: 0.044832, Val Loss: 0.039671, LR: 2.05e-08
# Epoch 22, Train Loss: 0.041996, Val Loss: 0.101412, LR: 2.03e-08
# Epoch 23, Train Loss: 0.042422, Val Loss: 0.104892, LR: 2.01e-08
# Epoch 24, Train Loss: 0.053192, Val Loss: 0.134517, LR: 1.98e-08
# Epoch 25, Train Loss: 0.039070, Val Loss: 0.138377, LR: 1.96e-08
# Epoch 26, Train Loss: 0.040477, Val Loss: 0.093202, LR: 1.93e-08
# Epoch 27, Train Loss: 0.043717, Val Loss: 0.106813, LR: 1.91e-08
# Epoch 28, Train Loss: 0.044649, Val Loss: 0.074399, LR: 1.88e-08
# Epoch 29, Train Loss: 0.042844, Val Loss: 0.217166, LR: 1.86e-08
# Epoch 30, Train Loss: 0.044197, Val Loss: 0.072953, LR: 1.83e-08
# Epoch 31, Train Loss: 0.048585, Val Loss: 0.066717, LR: 1.80e-08
# Epoch 32, Train Loss: 0.045227, Val Loss: 0.218765, LR: 1.77e-08
# Epoch 33, Train Loss: 0.046963, Val Loss: 0.702618, LR: 1.74e-08
# Early stopping triggered. Stopping training at epoch 33.
# Finished training.
# Model saved
# Model validation Loss over 60 steps: 0.037449
# Model validation Loss over full sequence: 0.056597
# CUDA before -> allocated: 43 MB, reserved: 5588 MB
# CUDA after  -> allocated: 43 MB, reserved: 100 MB
# Remaining live CUDA tensors: 146

# %%
plt.plot(unroll_array, val_loss_full_array, marker='x', label='Val Loss (Full Sequence)')
plt.xticks(unroll_array)
plt.xlabel("Unroll Steps")
plt.ylabel("Validation Loss")
plt.title("Validation Loss vs Unroll Steps")
plt.legend()
plt.grid()
plt.show()

# %%
UNROLL_STEPS = 10
checkpoint_name = f"CNN_RES_UNROLL_{UNROLL_STEPS}.pth"
model.load_state_dict(torch.load(f"models/{model_name}.pth", weights_only=True))
model.eval()
# Out:
# CNN_RES(
#   (conv_in): Conv1d(1, 256, kernel_size=(1,), stride=(1,), bias=False)
#   (bn_in): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (res_blocks): Sequential(
#     (0): ResidualBlock1D(
#       (conv1): Conv1d(256, 256, kernel_size=(5,), stride=(1,), bias=False)
#       (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv1d(256, 256, kernel_size=(5,), stride=(1,), bias=False)
#       (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): ResidualBlock1D(
#       (conv1): Conv1d(256, 256, kernel_size=(5,), stride=(1,), bias=False)
#       (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv1d(256, 256, kernel_size=(5,), stride=(1,), bias=False)
#       (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): ResidualBlock1D(
#       (conv1): Conv1d(256, 256, kernel_size=(5,), stride=(1,), bias=False)
#       (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv1d(256, 256, kernel_size=(5,), stride=(1,), bias=False)
#       (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): ResidualBlock1D(
#       (conv1): Conv1d(256, 256, kernel_size=(5,), stride=(1,), bias=False)
#       (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv1d(256, 256, kernel_size=(5,), stride=(1,), bias=False)
#       (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv_out): Conv1d(256, 1, kernel_size=(1,), stride=(1,))
# )

# %%
#sample the train_loader
sample = next(iter(train_loader))

x, y = sample

x = x.to(device)
y = y.to(device)

with torch.no_grad():
	y_pred = model(x)
	
y_pred = y_pred.cpu()
x = x.cpu()
y = y.cpu()
#plot 
plt.figure(figsize=(10,5), dpi=300)
plt.plot(x[0].numpy(), label='Input')
plt.plot(y[0][0].numpy(), label='Target')
plt.plot(y_pred[0], label='Prediction')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #sample the train_loader
# ----> 2 sample = next(iter(train_loader))
#       4 x, y = sample
#       6 x = x.to(device)
#
# NameError: name 'train_loader' is not defined

# %%
import numpy as np
import os

model.eval()

npz_files = [f for f in os.listdir(DATA_DIR) if f.endswith('.npz')]
if not npz_files:
    print("No .npz files found for evaluation.")
    
file_num = np.random.randint(0, len(npz_files) - 1)
data_path = os.path.join(DATA_DIR, npz_files[file_num])
raw_data = np.load(data_path)['DataGenerator-Mesh-1D-Internal']

rollout_steps = raw_data.shape[0] - 1

start_index = 0

x0_np = raw_data[start_index]
ground_truth = raw_data[start_index : start_index + rollout_steps + 1]

predictions = [x0_np]
current_x = torch.from_numpy(x0_np).float().unsqueeze(0).to(device)

with torch.no_grad():
    for _ in range(rollout_steps):
        bc_left = current_x[:, -1:]
        bc_right = current_x[:, :1]
        padded_input = pad_with_ghost_cells(current_x, bc_left, bc_right)
        
        y_pred = model(padded_input)

        predictions.append(y_pred.squeeze().cpu())
        current_x = y_pred

predictions = np.array(predictions)
mse = np.mean((predictions - ground_truth)**2)

# --- 1. Calculate all necessary data for plotting ---
mse_over_steps = np.mean((predictions - ground_truth)**2, axis=1)
print(f"Rollout MSE over {rollout_steps} steps: {mse_over_steps.mean():.6f}")

# Determine the shared color limits
vmin = ground_truth.min()
vmax = ground_truth.max()


# --- 2. Create a 3x1 subplot layout with a shared X-axis ---
# The key change is sharex=True, which links the x-axes of all subplots.
fig, axes = plt.subplots(3, 1, figsize=(10, 8), sharex=True,
                         gridspec_kw={'height_ratios': [1, 1, 0.7]}) # Give less height to the MSE plot

# --- Plot 1: Ground Truth (now on top) ---
im = axes[0].imshow(ground_truth.T, aspect='auto', origin='lower', vmin=vmin, vmax=vmax, cmap='viridis')
axes[0].set_title('Ground Truth')
axes[0].set_ylabel('Spatial Coordinate')

# --- Plot 2: Surrogate Rollout (in the middle) ---
axes[1].imshow(predictions.T, aspect='auto', origin='lower', vmin=vmin, vmax=vmax, cmap='viridis')
axes[1].set_title('Autoregressive Surrogate Model')
axes[1].set_ylabel('Spatial Coordinate')

# --- Plot 3: MSE over Time Steps (at the bottom) ---
axes[2].plot(mse_over_steps, color='r')
axes[2].set_title('Mean Squared Error (MSE) Over Time')
axes[2].set_xlabel('Time Step')
axes[2].set_ylabel('MSE')
axes[2].set_yscale("log")
axes[2].grid(True, which="both", linestyle="--", linewidth=0.5)
# Set explicit x-axis limits to match the imshow extent
axes[2].set_xlim(-0.5, len(mse_over_steps) - 0.5)

# --- THE KEY CHANGES START HERE ---

# --- 3. Manually create a new axis for the colorbar ---
# The rectangle's coordinates are in "figure fractions" (0 to 1).
# [left, bottom, width, height]
cbar_ax = fig.add_axes([0.275, 0.875, 0.5, 0.02]) # Positioned at the top

# --- 4. Draw the colorbar into the new axis using the `cax` argument ---
cbar = fig.colorbar(im, cax=cbar_ax, orientation='horizontal', label='Velocity')
cbar.ax.xaxis.set_ticks_position('top')
cbar.ax.xaxis.set_label_position('top')


fig.tight_layout(rect=[0, 0, 1, 0.875]) # Adjust layout to make space for the main title
fig.suptitle(f"1D Burgers' Equation Rollout Comparison", fontsize=16)

# Save and show the combined figure
plt.savefig('rollout_comparison.svg', dpi=300)
plt.show()
# Out:
# Rollout MSE over 100 steps: 0.097902
# /tmp/ipykernel_38431/598890236.py:85: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0, 1, 0.875]) # Adjust layout to make space for the main title

# %%
# !jupyter nbconvert --to script train_burgers_bptt.ipynb
# Out:
# [NbConvertApp] Converting notebook train_burgers_bptt.ipynb to script
# [NbConvertApp] Writing 12409 bytes to train_burgers_bptt.py
